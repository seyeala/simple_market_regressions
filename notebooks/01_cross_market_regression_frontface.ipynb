# %% [markdown]
# # Cross-market regression front face
# This notebook intentionally delegates all logic to repository modules.

# %%
from cross_market_regression.config import load_config
from cross_market_regression.data.dataset import build_dataset

config = load_config('../configs/examples/ewy_kospi.yaml')
# rows = build_dataset(config)  # requires local CSV data
config.name
